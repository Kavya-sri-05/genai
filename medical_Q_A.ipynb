# %% [markdown]
# <a href="https://colab.research.google.com/github/Kavya-sri-05/genai/blob/main/medical_Q_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install necessary packages
# !pip install pymed google-generativeai

# Import required libraries
import google.generativeai as genai
from pymed import PubMed

# Configure the Gemini API key
genai.configure(api_key="AIzaSyBe7E_z4LXe2AXwfBxAWtHYr87Jfwug09M")

# Initialize PubMed client
pubmed = PubMed(tool="MedicalDiagnosisApp", email="your_email@example.com")

# Function to fetch PubMed articles based on a query
def fetch_pubmed_articles(query, max_results=5):
    articles = pubmed.query(query, max_results=max_results)
    return "\n".join([f"{article.title}" for article in articles])

# Function to generate a diagnosis using Gemini API
def generate_diagnosis(pubmed_data):
    prompt = f"""
    Based on the following PubMed articles:

    {pubmed_data}

    Provide a concise diagnosis and possible treatment options.
    """
    response = genai.GenerativeModel("gemini-2.0-flash").generate_content(prompt)
    return response.text

# Main function to diagnose a medical condition
def diagnose_medical_condition(query):
    pubmed_data = fetch_pubmed_articles(query)
    diagnosis = generate_diagnosis(pubmed_data)
    return diagnosis

# User input and response
query = input("Please enter your medical question: ")
diagnosis = diagnose_medical_condition(query)
print(f"Diagnosis and treatment suggestions for '{query}':\n{diagnosis}")
# Out:
# ...
# Please enter your medical question: What are the symptoms of diabetes?
# Diagnosis and treatment suggestions for 'What are the symptoms of diabetes?':
# Okay, based on the provided PubMed article titles, here's a breakdown of potential diagnoses and possible treatment options:
#
# **1. Gestational Diabetes (GDM) in Ghana and Switzerland:**
#
# *   **Diagnosis:** Gestational Diabetes Mellitus (GDM). This is a type of diabetes that develops during pregnancy. The "G-MUM study" focuses on comparative differences in metabolic, mental health, and perinatal outcomes between women with GDM in Ghana and Switzerland.
# *   **Possible Treatment Options:**
#     *   **Dietary Management:**  Controlling carbohydrate intake, monitoring blood glucose levels.
#     *   **Exercise:** Regular physical activity, as appropriate for pregnancy.
#     *   **Medication (if needed):** Insulin or oral hypoglycemic agents (e.g., Metformin), if diet and exercise are insufficient to control blood glucose.
# ...

# %%
# !pip install pymed
# !pip install google-generativeai
# !pip install faiss-cpu
# !pip install langchain-community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 29.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.0 MB/s eta 0:00:00
# ...

# %%
# First, uninstall any existing versions to avoid conflicts
# !pip uninstall -y google-generativeai
# !pip uninstall -y genai

# Install the correct package
# !pip install --upgrade google-generativeai
# Out:
# Found existing installation: google-generativeai 0.8.4
# Uninstalling google-generativeai-0.8.4:
#   Successfully uninstalled google-generativeai-0.8.4
# WARNING: Skipping genai as it is not installed.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 2.7 MB/s eta 0:00:00
# ...
